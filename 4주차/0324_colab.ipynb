# %% [markdown]
# <a href="https://colab.research.google.com/github/2sseul/JNU_BigDataProgramming_451307/blob/master/0324_colab.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive

drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !ls ./drive/MyDrive/Colab\ Notebooks -la
# Out:
# total 39
# -rw------- 1 root root 31920 Mar 24 02:30 prime_robot.png
# -rw------- 1 root root  7443 Mar 24 02:32 Untitled0.ipynb

# %%
import matplotlib.image as mpimg
import matplotlib.pyplot as plt

# %%
img = mpimg.imread('./drive/MyDrive/prime_robot.png')
plt.imshow(img)

# %%
from google.colab import files

# %%
uploaded = files.upload()
# Out:
#      <input type="file" id="files-aa38d239-3322-4a93-868c-9bd91bdbcc0f" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-aa38d239-3322-4a93-868c-9bd91bdbcc0f">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
import pandas as pd

# %%
uploaded = files.upload()
# Out:
#      <input type="file" id="files-94633744-c4d8-4789-b8e5-cbe54837bfae" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-94633744-c4d8-4789-b8e5-cbe54837bfae">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
df = pd.read_csv('./vehicle_prod.csv')
df.head(3)
# Out:
#   Unnamed: 0   2007   2008   2009   2010   2011
# 0      China   7.71   7.95  11.96  15.84  16.33
# 1         EU  19.02  17.71  15.00  16.70  17.48
# 2         US  10.47   8.45   5.58   7.60   8.40

# %%
img = mpimg.imread('./drive/MyDrive/prime_cat.png')

# %%
plt.imshow(img)

# %%
person = {'이름' : '홍길동', '나이' : 26, '몸무게' : 82}

# %%
print('person의 키들 :', list(person.keys()))
# Out:
# person의 키들 : ['이름', '나이', '몸무게']

# %%
print('person의 value들: ', list(person.values()))
# Out:
# person의 value들:  ['홍길동', 26, 82]

# %%
print('person의 아이템들: ', list(person.items()))
# Out:
# person의 아이템들:  [('이름', '홍길동'), ('나이', 26), ('몸무게', 82)]
